# %%
import cv2

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt


PATH_IMG ="C:/Users/katta/Desktop/TLF/ChallengeLabSid/test/model/003218_0.jpg"
image = cv2.imread(PATH_IMG,0)
_, seg_mask = cv2.threshold(image, 225, 255, cv2.THRESH_BINARY_INV)
cv2.imwrite('C:/Users/katta/Desktop/TLF/ChallengeLabSid/test/modelmask/003218_0.jpg',seg_mask)

plt.imshow(seg_mask,'gray',vmin=0,vmax=255)
plt.title('my picture')
plt.show()
